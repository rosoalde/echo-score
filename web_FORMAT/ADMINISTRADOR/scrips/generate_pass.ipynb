# %% [markdown]
# # GENERAR PASSWORD para ADMIN

# %%
from passlib.context import CryptContext

pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

# %%
#################
#################

#ej: password = "hola mundo"

password = ""

#################
#################

# %%
pwd_context.hash(password)

print(pwd_context)

# %% [markdown]
# # Con esa contraseña generada, te vas a "config/.env y cambias el valor de ADMIN_PASS
# # Recuerda que la contraseña debe estar entre comillas
